# %%
import requests
import pandas as pd
import numpy as np

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"
resp=requests.get(url)
type(resp)
# Out:
# requests.models.Response

# %%
resp
# Out:
# <Response [200]>

# %%
data=resp.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42718',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42718/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42718/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42718/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42718',
#   'id': 952351519,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Njk2NTYxMDY4',
#   'number': 42718,
#   'title': 'TST: Fixed doctest in Styler.to_latex #42672',
#   'user': {'login': 'willie3838',
#    'id': 21048435,
#    'node_id': 'MDQ6VXNlcjIxMDQ4NDM1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21048435?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/willie3838',
#    'html_url': 'https://github.com/willie3838',
# ...

# %%
perfect=pd.DataFrame(data)
perfect
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
data[0]["user"]["node_id"]
# Out:
# 'MDQ6VXNlcjIxMDQ4NDM1'

# %%
perfect.to_csv(r"C:\Users\ADMIN\Desktop\Json.csv")

# %%
date=pd.date_range("04/12/2021",periods=7)
date
# Out:
# DatetimeIndex(['2021-04-12', '2021-04-13', '2021-04-14', '2021-04-15',
#                '2021-04-16', '2021-04-17', '2021-04-18'],
#               dtype='datetime64[ns]', freq='D')

# %%
ts=pd.Series(np.arange(7),index=date)
ts
# Out:
# 2021-04-12    0
# 2021-04-13    1
# 2021-04-14    2
# 2021-04-15    3
# 2021-04-16    4
# 2021-04-17    5
# 2021-04-18    6
# Freq: D, dtype: int32

# %%
frame=pd.DataFrame(ts)
frame
# Out:
#             0
# 2021-04-12  0
# 2021-04-13  1
# 2021-04-14  2
# 2021-04-15  3
# 2021-04-16  4
# 2021-04-17  5
# 2021-04-18  6

# %%
val=np.array([1,2,np.nan,3,4,5,6,7])
val
# Out:
# array([ 1.,  2., nan,  3.,  4.,  5.,  6.,  7.])

# %%
6+np.nan
# Out:
# nan

# %%
7*np.nan
# Out:
# nan

# %%
np.nansum(val)
# Out:
# 28.0

# %%
val2=pd.Series([1,2,np.nan,4,5,None])
val2
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    5.0
# 5    NaN
# dtype: float64

# %%
val2
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    5.0
# 5    NaN
# dtype: float64

# %%
val2.fillna(value="--")
# Out:
# 0     1
# 1     2
# 2    --
# 3     4
# 4     5
# 5    --
# dtype: object

# %%
val2
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    5.0
# 5    NaN
# dtype: float64

# %%
val2
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    5.0
# 5    NaN
# dtype: float64

# %%
val2.fillna(method="bfill")
# Out:
# 0    1.0
# 1    2.0
# 2    4.0
# 3    4.0
# 4    5.0
# 5    NaN
# dtype: float64

# %%
val2.fillna(method="ffill")
# Out:
# 0    1.0
# 1    2.0
# 2    2.0
# 3    4.0
# 4    5.0
# 5    5.0
# dtype: float64

# %%
val2
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    5.0
# 5    NaN
# dtype: float64

# %%
val3=pd.read_excel(r"C:\Users\ADMIN\Desktop\companydata.xlsx")

# %%
val3
# Out:
#       regiment company     name  pretestscore  posttestscore  class cabin
# 0   Nighthawks     1st   sanjay             1              0      1   A01
# 1   Nighthawks     1st  sandeep             0              1      2   A02
# 2   Nighthawks     2nd    sonia             1              0      3   A03
# 3   Nighthawks     2nd   sunita             0              1      1   B04
# 4     Dragoons     1st  parkash             1              0      2   B05
# 5     Dragoons     1st     sonu             0              1      3   B06
# 6     Dragoons     2nd    vinod             0              0      1   C07
# 7     Dragoons     2nd   mukesh             1              0      1   C08
# 8       Scouts     1st   harish             1              0      2   NaN
# 9       Scouts     1st   sushma             1              0      3   NaN
# 10      Scouts     2nd    suman             1              0      3   NaN
# 11      Scouts     2nd     baby             0              1      3   NaN

# %%
val4=pd.DataFrame(val3)
val4
# Out:
#       regiment company     name  pretestscore  posttestscore  class cabin
# 0   Nighthawks     1st   sanjay             1              0      1   A01
# 1   Nighthawks     1st  sandeep             0              1      2   A02
# 2   Nighthawks     2nd    sonia             1              0      3   A03
# 3   Nighthawks     2nd   sunita             0              1      1   B04
# 4     Dragoons     1st  parkash             1              0      2   B05
# 5     Dragoons     1st     sonu             0              1      3   B06
# 6     Dragoons     2nd    vinod             0              0      1   C07
# 7     Dragoons     2nd   mukesh             1              0      1   C08
# 8       Scouts     1st   harish             1              0      2   NaN
# 9       Scouts     1st   sushma             1              0      3   NaN
# 10      Scouts     2nd    suman             1              0      3   NaN
# 11      Scouts     2nd     baby             0              1      3   NaN

# %%
val3.set_index(["regiment","company"],drop=True)
# Out:
#                        name  pretestscore  posttestscore  class cabin
# regiment   company
# Nighthawks 1st       sanjay             1              0      1   A01
#            1st      sandeep             0              1      2   A02
#            2nd        sonia             1              0      3   A03
#            2nd       sunita             0              1      1   B04
# Dragoons   1st      parkash             1              0      2   B05
#            1st         sonu             0              1      3   B06
#            2nd        vinod             0              0      1   C07
#            2nd       mukesh             1              0      1   C08
# Scouts     1st       harish             1              0      2   NaN
#            1st       sushma             1              0      3   NaN
#            2nd        suman             1              0      3   NaN
#            2nd         baby             0              1      3   NaN

# %%
val3
# Out:
#       regiment company     name  pretestscore  posttestscore  class cabin
# 0   Nighthawks     1st   sanjay             1              0      1   A01
# 1   Nighthawks     1st  sandeep             0              1      2   A02
# 2   Nighthawks     2nd    sonia             1              0      3   A03
# 3   Nighthawks     2nd   sunita             0              1      1   B04
# 4     Dragoons     1st  parkash             1              0      2   B05
# 5     Dragoons     1st     sonu             0              1      3   B06
# 6     Dragoons     2nd    vinod             0              0      1   C07
# 7     Dragoons     2nd   mukesh             1              0      1   C08
# 8       Scouts     1st   harish             1              0      2   NaN
# 9       Scouts     1st   sushma             1              0      3   NaN
# 10      Scouts     2nd    suman             1              0      3   NaN
# 11      Scouts     2nd     baby             0              1      3   NaN

# %%
val3
# Out:
#       regiment company     name  pretestscore  posttestscore  class cabin
# 0   Nighthawks     1st   sanjay             1              0      1   A01
# 1   Nighthawks     1st  sandeep             0              1      2   A02
# 2   Nighthawks     2nd    sonia             1              0      3   A03
# 3   Nighthawks     2nd   sunita             0              1      1   B04
# 4     Dragoons     1st  parkash             1              0      2   B05
# 5     Dragoons     1st     sonu             0              1      3   B06
# 6     Dragoons     2nd    vinod             0              0      1   C07
# 7     Dragoons     2nd   mukesh             1              0      1   C08
# 8       Scouts     1st   harish             1              0      2   NaN
# 9       Scouts     1st   sushma             1              0      3   NaN
# 10      Scouts     2nd    suman             1              0      3   NaN
# 11      Scouts     2nd     baby             0              1      3   NaN

# %%
val4
# Out:
#       regiment company     name  pretestscore  posttestscore  class cabin
# 0   Nighthawks     1st   sanjay             1              0      1   A01
# 1   Nighthawks     1st  sandeep             0              1      2   A02
# 2   Nighthawks     2nd    sonia             1              0      3   A03
# 3   Nighthawks     2nd   sunita             0              1      1   B04
# 4     Dragoons     1st  parkash             1              0      2   B05
# 5     Dragoons     1st     sonu             0              1      3   B06
# 6     Dragoons     2nd    vinod             0              0      1   C07
# 7     Dragoons     2nd   mukesh             1              0      1   C08
# 8       Scouts     1st   harish             1              0      2   NaN
# 9       Scouts     1st   sushma             1              0      3   NaN
# 10      Scouts     2nd    suman             1              0      3   NaN
# 11      Scouts     2nd     baby             0              1      3   NaN

# %%
data100=pd.read_excel(r"C:\Users\ADMIN\Desktop\companydata.xlsx")
data100.head()
# Out:
#      regiment company     name  pretestscore  posttestscore  class cabin
# 0  Nighthawks     1st   sanjay             1              0      1   A01
# 1  Nighthawks     1st  sandeep             0              1      2   A02
# 2  Nighthawks     2nd    sonia             1              0      3   A03
# 3  Nighthawks     2nd   sunita             0              1      1   B04
# 4    Dragoons     1st  parkash             1              0      2   B05

# %%
new_survived=pd.Categorical(data100["posttestscore"])
new_survived=new_survived.rename_categories(["Dead","Leave"])
new_survived.describe()
# Out:
#             counts     freqs
# categories
# Dead             8  0.666667
# Leave            4  0.333333

# %%
new_class=pd.Categorical(data100["class"])
new_class=new_class.rename_categories(["Class 1","Class 2","Class 3"])
new_class.describe()
# Out:
#             counts     freqs
# categories
# Class 1          4  0.333333
# Class 2          3  0.250000
# Class 3          5  0.416667

# %%
data100["class"].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
data100["cabin"].unique()
# Out:
# array(['A01', 'A02', 'A03', 'B04', 'B05', 'B06', 'C07', 'C08', nan],
#       dtype=object)

# %%
data100["class"]=new_class

# %%
data100
# Out:
#       regiment company     name  pretestscore  posttestscore    class cabin
# 0   Nighthawks     1st   sanjay             1              0  Class 1   A01
# 1   Nighthawks     1st  sandeep             0              1  Class 2   A02
# 2   Nighthawks     2nd    sonia             1              0  Class 3   A03
# 3   Nighthawks     2nd   sunita             0              1  Class 1   B04
# 4     Dragoons     1st  parkash             1              0  Class 2   B05
# 5     Dragoons     1st     sonu             0              1  Class 3   B06
# 6     Dragoons     2nd    vinod             0              0  Class 1   C07
# 7     Dragoons     2nd   mukesh             1              0  Class 1   C08
# 8       Scouts     1st   harish             1              0  Class 2   NaN
# 9       Scouts     1st   sushma             1              0  Class 3   NaN
# 10      Scouts     2nd    suman             1              0  Class 3   NaN
# ...

# %%
data100["Status"]=new_survived

# %%
data100
# Out:
#       regiment company     name  pretestscore  posttestscore    class cabin  \
# 0   Nighthawks     1st   sanjay             1              0  Class 1   A01
# 1   Nighthawks     1st  sandeep             0              1  Class 2   A02
# 2   Nighthawks     2nd    sonia             1              0  Class 3   A03
# 3   Nighthawks     2nd   sunita             0              1  Class 1   B04
# 4     Dragoons     1st  parkash             1              0  Class 2   B05
# 5     Dragoons     1st     sonu             0              1  Class 3   B06
# 6     Dragoons     2nd    vinod             0              0  Class 1   C07
# 7     Dragoons     2nd   mukesh             1              0  Class 1   C08
# 8       Scouts     1st   harish             1              0  Class 2   NaN
# 9       Scouts     1st   sushma             1              0  Class 3   NaN
# 10      Scouts     2nd    suman             1              0  Class 3   NaN
# ...

# %%
new_char=data100["cabin"].astype(str)
new_line=np.array([cabin[0] for cabin in new_char])
new_line=pd.Categorical(new_line)
new_line.describe()
# Out:
#             counts     freqs
# categories
# A                3  0.250000
# B                3  0.250000
# C                2  0.166667
# n                4  0.333333

# %%
data100["Cabin Status"]=new_line

# %%
data100
# Out:
#       regiment company     name  pretestscore  posttestscore    class cabin  \
# 0   Nighthawks     1st   sanjay             1              0  Class 1   A01
# 1   Nighthawks     1st  sandeep             0              1  Class 2   A02
# 2   Nighthawks     2nd    sonia             1              0  Class 3   A03
# 3   Nighthawks     2nd   sunita             0              1  Class 1   B04
# 4     Dragoons     1st  parkash             1              0  Class 2   B05
# 5     Dragoons     1st     sonu             0              1  Class 3   B06
# 6     Dragoons     2nd    vinod             0              0  Class 1   C07
# 7     Dragoons     2nd   mukesh             1              0  Class 1   C08
# 8       Scouts     1st   harish             1              0  Class 2   NaN
# 9       Scouts     1st   sushma             1              0  Class 3   NaN
# 10      Scouts     2nd    suman             1              0  Class 3   NaN
# ...

# %%
val3
# Out:
#       regiment company     name  pretestscore  posttestscore  class cabin
# 0   Nighthawks     1st   sanjay             1              0      1   A01
# 1   Nighthawks     1st  sandeep             0              1      2   A02
# 2   Nighthawks     2nd    sonia             1              0      3   A03
# 3   Nighthawks     2nd   sunita             0              1      1   B04
# 4     Dragoons     1st  parkash             1              0      2   B05
# 5     Dragoons     1st     sonu             0              1      3   B06
# 6     Dragoons     2nd    vinod             0              0      1   C07
# 7     Dragoons     2nd   mukesh             1              0      1   C08
# 8       Scouts     1st   harish             1              0      2   NaN
# 9       Scouts     1st   sushma             1              0      3   NaN
# 10      Scouts     2nd    suman             1              0      3   NaN
# 11      Scouts     2nd     baby             0              1      3   NaN

# %%
data100
# Out:
#       regiment company     name  pretestscore  posttestscore    class cabin  \
# 0   Nighthawks     1st   sanjay             1              0  Class 1   A01
# 1   Nighthawks     1st  sandeep             0              1  Class 2   A02
# 2   Nighthawks     2nd    sonia             1              0  Class 3   A03
# 3   Nighthawks     2nd   sunita             0              1  Class 1   B04
# 4     Dragoons     1st  parkash             1              0  Class 2   B05
# 5     Dragoons     1st     sonu             0              1  Class 3   B06
# 6     Dragoons     2nd    vinod             0              0  Class 1   C07
# 7     Dragoons     2nd   mukesh             1              0  Class 1   C08
# 8       Scouts     1st   harish             1              0  Class 2   NaN
# 9       Scouts     1st   sushma             1              0  Class 3   NaN
# 10      Scouts     2nd    suman             1              0  Class 3   NaN
# ...

# %%
data100.set_index(["regiment","company"])
# Out:
#                        name  pretestscore  posttestscore    class cabin  \
# regiment   company
# Nighthawks 1st       sanjay             1              0  Class 1   A01
#            1st      sandeep             0              1  Class 2   A02
#            2nd        sonia             1              0  Class 3   A03
#            2nd       sunita             0              1  Class 1   B04
# Dragoons   1st      parkash             1              0  Class 2   B05
#            1st         sonu             0              1  Class 3   B06
#            2nd        vinod             0              0  Class 1   C07
#            2nd       mukesh             1              0  Class 1   C08
# Scouts     1st       harish             1              0  Class 2   NaN
#            1st       sushma             1              0  Class 3   NaN
#            2nd        suman             1              0  Class 3   NaN
#            2nd         baby             0              1  Class 3   NaN
#
# ...

# %%
data100["Cabin Status"].value_counts()
# Out:
# n    4
# B    3
# A    3
# C    2
# Name: Cabin Status, dtype: int64

# %%
new_data = data100["Cabin Status"].unique()

# %%
new_data.value_counts()
# Out:
# A    1
# B    1
# C    1
# n    1
# dtype: int64

# %%
data100.set_index(["Cabin Status"])
# Out:
#                 regiment company     name  pretestscore  posttestscore  \
# Cabin Status
# A             Nighthawks     1st   sanjay             1              0
# A             Nighthawks     1st  sandeep             0              1
# A             Nighthawks     2nd    sonia             1              0
# B             Nighthawks     2nd   sunita             0              1
# B               Dragoons     1st  parkash             1              0
# B               Dragoons     1st     sonu             0              1
# C               Dragoons     2nd    vinod             0              0
# C               Dragoons     2nd   mukesh             1              0
# n                 Scouts     1st   harish             1              0
# n                 Scouts     1st   sushma             1              0
# n                 Scouts     2nd    suman             1              0
# n                 Scouts     2nd     baby             0              1
#
# ...

# %%
data100.set_index(["regiment","company","Cabin Status"])
# Out:
#                                     name  pretestscore  posttestscore  \
# regiment   company Cabin Status
# Nighthawks 1st     A              sanjay             1              0
#                    A             sandeep             0              1
#            2nd     A               sonia             1              0
#                    B              sunita             0              1
# Dragoons   1st     B             parkash             1              0
#                    B                sonu             0              1
#            2nd     C               vinod             0              0
#                    C              mukesh             1              0
# Scouts     1st     n              harish             1              0
#                    n              sushma             1              0
#            2nd     n               suman             1              0
#                    n                baby             0              1
#
# ...

# %%
data100.to_csv(r"C:\Users\ADMIN\Desktop\myprocessdata.csv")

# %%
missing=np.where(data100["cabin"].isnull()==True)
missing
# Out:
# (array([ 8,  9, 10, 11], dtype=int64),)

# %%
len(missing[0])
# Out:
# 4

# %%
index=np.where(data100["class"]==max(data100["class"]))
index
# Out:
# (array([ 2,  5,  9, 10, 11], dtype=int64),)

# %%
data100
# Out:
#       regiment company     name  pretestscore  posttestscore    class cabin  \
# 0   Nighthawks     1st   sanjay             1              0  Class 1   A01
# 1   Nighthawks     1st  sandeep             0              1  Class 2   A02
# 2   Nighthawks     2nd    sonia             1              0  Class 3   A03
# 3   Nighthawks     2nd   sunita             0              1  Class 1   B04
# 4     Dragoons     1st  parkash             1              0  Class 2   B05
# 5     Dragoons     1st     sonu             0              1  Class 3   B06
# 6     Dragoons     2nd    vinod             0              0  Class 1   C07
# 7     Dragoons     2nd   mukesh             1              0  Class 1   C08
# 8       Scouts     1st   harish             1              0  Class 2   NaN
# 9       Scouts     1st   sushma             1              0  Class 3   NaN
# 10      Scouts     2nd    suman             1              0  Class 3   NaN
# ...

# %%
data100.loc[index]
# Out:
#       regiment company    name  pretestscore  posttestscore    class cabin  \
# 2   Nighthawks     2nd   sonia             1              0  Class 3   A03
# 5     Dragoons     1st    sonu             0              1  Class 3   B06
# 9       Scouts     1st  sushma             1              0  Class 3   NaN
# 10      Scouts     2nd   suman             1              0  Class 3   NaN
# 11      Scouts     2nd    baby             0              1  Class 3   NaN
#
#    Status Cabin Status
# 2    Dead            A
# 5   Leave            B
# 9    Dead            n
# 10   Dead            n
# 11  Leave            n

# %%
data100
# Out:
#       regiment company     name  pretestscore  posttestscore    class cabin  \
# 0   Nighthawks     1st   sanjay             1              0  Class 1   A01
# 1   Nighthawks     1st  sandeep             0              1  Class 2   A02
# 2   Nighthawks     2nd    sonia             1              0  Class 3   A03
# 3   Nighthawks     2nd   sunita             0              1  Class 1   B04
# 4     Dragoons     1st  parkash             1              0  Class 2   B05
# 5     Dragoons     1st     sonu             0              1  Class 3   B06
# 6     Dragoons     2nd    vinod             0              0  Class 1   C07
# 7     Dragoons     2nd   mukesh             1              0  Class 1   C08
# 8       Scouts     1st   harish             1              0  Class 2   NaN
# 9       Scouts     1st   sushma             1              0  Class 3   NaN
# 10      Scouts     2nd    suman             1              0  Class 3   NaN
# ...

# %%
data100
# Out:
#       regiment company     name  pretestscore  posttestscore    class cabin  \
# 0   Nighthawks     1st   sanjay             1              0  Class 1   A01
# 1   Nighthawks     1st  sandeep             0              1  Class 2   A02
# 2   Nighthawks     2nd    sonia             1              0  Class 3   A03
# 3   Nighthawks     2nd   sunita             0              1  Class 1   B04
# 4     Dragoons     1st  parkash             1              0  Class 2   B05
# 5     Dragoons     1st     sonu             0              1  Class 3   B06
# 6     Dragoons     2nd    vinod             0              0  Class 1   C07
# 7     Dragoons     2nd   mukesh             1              0  Class 1   C08
# 8       Scouts     1st   harish             1              0  Class 2   NaN
# 9       Scouts     1st   sushma             1              0  Class 3   NaN
# 10      Scouts     2nd    suman             1              0  Class 3   NaN
# ...

# %%
data100["Index"] =list(range(1,13))

# %%
data100
# Out:
#       regiment company     name  pretestscore  posttestscore    class cabin  \
# 0   Nighthawks     1st   sanjay             1              0  Class 1   A01
# 1   Nighthawks     1st  sandeep             0              1  Class 2   A02
# 2   Nighthawks     2nd    sonia             1              0  Class 3   A03
# 3   Nighthawks     2nd   sunita             0              1  Class 1   B04
# 4     Dragoons     1st  parkash             1              0  Class 2   B05
# 5     Dragoons     1st     sonu             0              1  Class 3   B06
# 6     Dragoons     2nd    vinod             0              0  Class 1   C07
# 7     Dragoons     2nd   mukesh             1              0  Class 1   C08
# 8       Scouts     1st   harish             1              0  Class 2   NaN
# 9       Scouts     1st   sushma             1              0  Class 3   NaN
# 10      Scouts     2nd    suman             1              0  Class 3   NaN
# ...

# %%
data100.set_index(["Index"])
# Out:
#          regiment company     name  pretestscore  posttestscore    class  \
# Index
# 1      Nighthawks     1st   sanjay             1              0  Class 1
# 2      Nighthawks     1st  sandeep             0              1  Class 2
# 3      Nighthawks     2nd    sonia             1              0  Class 3
# 4      Nighthawks     2nd   sunita             0              1  Class 1
# 5        Dragoons     1st  parkash             1              0  Class 2
# 6        Dragoons     1st     sonu             0              1  Class 3
# 7        Dragoons     2nd    vinod             0              0  Class 1
# 8        Dragoons     2nd   mukesh             1              0  Class 1
# 9          Scouts     1st   harish             1              0  Class 2
# 10         Scouts     1st   sushma             1              0  Class 3
# 11         Scouts     2nd    suman             1              0  Class 3
# 12         Scouts     2nd     baby             0              1  Class 3
#
# ...

# %%
data100.set_index([list(range(1,13))],inplace=True)

# %%
data100
# Out:
#       regiment company     name  pretestscore  posttestscore    class cabin  \
# 1   Nighthawks     1st   sanjay             1              0  Class 1   A01
# 2   Nighthawks     1st  sandeep             0              1  Class 2   A02
# 3   Nighthawks     2nd    sonia             1              0  Class 3   A03
# 4   Nighthawks     2nd   sunita             0              1  Class 1   B04
# 5     Dragoons     1st  parkash             1              0  Class 2   B05
# 6     Dragoons     1st     sonu             0              1  Class 3   B06
# 7     Dragoons     2nd    vinod             0              0  Class 1   C07
# 8     Dragoons     2nd   mukesh             1              0  Class 1   C08
# 9       Scouts     1st   harish             1              0  Class 2   NaN
# 10      Scouts     1st   sushma             1              0  Class 3   NaN
# 11      Scouts     2nd    suman             1              0  Class 3   NaN
# ...
